# %% [markdown]
# <a href="https://colab.research.google.com/github/MIssionSarker/MIssionSarker/blob/main/Firstprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SKill Morph");
# Out:
# SKill Morph
